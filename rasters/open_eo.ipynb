# %%
import openeo
import geopandas as gpd

# %%
connection = openeo.connect('openeo.dataspace.copernicus.eu')
connection = connection.authenticate_oidc()
# Out:
# Visit <a href="https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=DNKW-LEPM" title="Authenticate at https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=DNKW-LEPM" target="_blank" rel="noopener noreferrer">https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=DNKW-LEPM</a> <a href="#" onclick="navigator.clipboard.writeText('https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=DNKW-LEPM');return false;" title="Copy authentication URL to clipboard">&#128203;</a> to authenticate.
# ✅ Authorized successfully
# Authenticated using device code flow.

# %%
collections = connection.list_collection_ids()
for i in collections:
    print(i)
# Out:
# SENTINEL3_OLCI_L1B
# SENTINEL3_SLSTR
# SENTINEL_5P_L2
# LANDSAT8_L2_BIMONTHLY_MOSAIC
# COPERNICUS_VEGETATION_PHENOLOGY_PRODUCTIVITY_10M_SEASON1
# COPERNICUS_VEGETATION_PHENOLOGY_PRODUCTIVITY_10M_SEASON2
# COPERNICUS_PLANT_PHENOLOGY_INDEX
# ESA_WORLDCOVER_10M_2020_V1
# ESA_WORLDCOVER_10M_2021_V2
# SENTINEL2_L1C
# SENTINEL2_L2A
# SENTINEL1_GRD
# COPERNICUS_30
# LANDSAT8_L2
# SENTINEL3_SYN_L2_SYN
# SENTINEL3_SLSTR_L2_LST
# SENTINEL1_GLOBAL_MOSAICS
# SENTINEL3_OLCI_L2_LAND
# SENTINEL3_OLCI_L2_WATER
# SENTINEL3_SYN_L2_AOD

# %%
enschede = gpd.read_file('../data/vectors/nederland_admin_areas.gpkg', layer='cities')
enschede = enschede[enschede['naam']=='Enschede']
enschede.head()
# Out:
#    identificatie      naam  code ligt_in_provincie_code  \
# 82        GM0153  Enschede  0153                     23
#
#    ligt_in_provincie_naam                                           geometry
# 82             Overijssel  MULTIPOLYGON (((252038.609 465222.168, 252036....
