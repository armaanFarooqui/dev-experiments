# %% [markdown]
# # Sources

# %% [markdown]
# ### 1. Nederland Administrative Areas
# * https://service.pdok.nl/kadaster/bestuurlijkegebieden/atom/v1_0/bestuurlijke_gebieden.xml

# %% [markdown]
# ### 2. India Administrative Areas
# * https://github.com/udit-001/india-maps-data/tree/main/geojson

# %% [markdown]
# ### 3. Nederland Population Statistics
# * https://www.cbs.nl/en-gb/figures/detail/37259eng?q=province
# * Cleaned: True

# %% [markdown]
# ### 4. Nederland Population Centres
#
# * https://service.pdok.nl/cbs/bevolkingskernen/2021/atom/bevolkingskernen_2021.xml
